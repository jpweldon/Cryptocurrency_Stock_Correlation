# %%
import pandas as pd
import cbpro
from dateutil import parser
from Historic_Crypto import HistoricalData
from Historic_Crypto import Cryptocurrencies
from Historic_Crypto import LiveCryptoData

# %%
c = cbpro.PublicClient()

# %%
new = HistoricalData('ETH-USD',300,'2020-06-01-00-00').retrieve_data()
# Out:
# Checking input parameters are in the correct format...
# Formatting Dates...
# Checking if ticker supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API...
# Ticker 'ETH-USD' found at the CoinBase Pro API, continuing to extraction...
# Data for chunk 0 of 411 extracted
# Data for chunk 1 of 411 extracted
# Data for chunk 2 of 411 extracted
# Data for chunk 3 of 411 extracted
# Data for chunk 4 of 411 extracted
# Data for chunk 5 of 411 extracted
# Data for chunk 6 of 411 extracted
# Data for chunk 7 of 411 extracted
# Data for chunk 8 of 411 extracted
# Data for chunk 9 of 411 extracted
# Data for chunk 10 of 411 extracted
# Data for chunk 11 of 411 extracted
# Data for chunk 12 of 411 extracted
# Data for chunk 13 of 411 extracted
# Data for chunk 14 of 411 extracted
# Data for chunk 15 of 411 extracted
# Data for chunk 16 of 411 extracted
# Data for chunk 17 of 411 extracted
# Data for chunk 18 of 411 extracted
# Data for chunk 19 of 411 extracted
# Data for chunk 20 of 411 extracted
# Data for chunk 21 of 411 extracted
# Data for chunk 22 of 411 extracted
# Data for chunk 23 of 411 extracted
# Data for chunk 24 of 411 extracted
# Data for chunk 25 of 411 extracted
# Data for chunk 26 of 411 extracted
# Data for chunk 27 of 411 extracted
# Data for chunk 28 of 411 extracted
# Data for chunk 29 of 411 extracted
# Data for chunk 30 of 411 extracted
# Data for chunk 31 of 411 extracted
# Data for chunk 32 of 411 extracted
# Data for chunk 33 of 411 extracted
# Data for chunk 34 of 411 extracted
# Data for chunk 35 of 411 extracted
# Data for chunk 36 of 411 extracted
# Data for chunk 37 of 411 extracted
# Data for chunk 38 of 411 extracted
# Data for chunk 39 of 411 extracted
# Data for chunk 40 of 411 extracted
# Data for chunk 41 of 411 extracted
# Data for chunk 42 of 411 extracted
# Data for chunk 43 of 411 extracted
# Data for chunk 44 of 411 extracted
# Data for chunk 45 of 411 extracted
# Data for chunk 46 of 411 extracted
# Data for chunk 47 of 411 extracted
# Data for chunk 48 of 411 extracted
# Data for chunk 49 of 411 extracted
# Data for chunk 50 of 411 extracted
# Data for chunk 51 of 411 extracted
# Data for chunk 52 of 411 extracted
# Data for chunk 53 of 411 extracted
# Data for chunk 54 of 411 extracted
# Data for chunk 55 of 411 extracted
# Data for chunk 56 of 411 extracted
# Data for chunk 57 of 411 extracted
# Data for chunk 58 of 411 extracted
# Data for chunk 59 of 411 extracted
# Data for chunk 60 of 411 extracted
# Data for chunk 61 of 411 extracted
# Data for chunk 62 of 411 extracted
# Data for chunk 63 of 411 extracted
# Data for chunk 64 of 411 extracted
# Data for chunk 65 of 411 extracted
# Data for chunk 66 of 411 extracted
# Data for chunk 67 of 411 extracted
# Data for chunk 68 of 411 extracted
# Data for chunk 69 of 411 extracted
# Data for chunk 70 of 411 extracted
# Data for chunk 71 of 411 extracted
# Data for chunk 72 of 411 extracted
# Data for chunk 73 of 411 extracted
# Data for chunk 74 of 411 extracted
# Data for chunk 75 of 411 extracted
# Data for chunk 76 of 411 extracted
# Data for chunk 77 of 411 extracted
# Data for chunk 78 of 411 extracted
# Data for chunk 79 of 411 extracted
# Data for chunk 80 of 411 extracted
# Data for chunk 81 of 411 extracted
# Data for chunk 82 of 411 extracted
# Data for chunk 83 of 411 extracted
# Data for chunk 84 of 411 extracted
# Data for chunk 85 of 411 extracted
# Data for chunk 86 of 411 extracted
# Data for chunk 87 of 411 extracted
# Data for chunk 88 of 411 extracted
# Data for chunk 89 of 411 extracted
# Data for chunk 90 of 411 extracted
# Data for chunk 91 of 411 extracted
# Data for chunk 92 of 411 extracted
# Data for chunk 93 of 411 extracted
# Data for chunk 94 of 411 extracted
# Data for chunk 95 of 411 extracted
# Data for chunk 96 of 411 extracted
# Data for chunk 97 of 411 extracted
# Data for chunk 98 of 411 extracted
# Data for chunk 99 of 411 extracted
# Data for chunk 100 of 411 extracted
# Data for chunk 101 of 411 extracted
# Data for chunk 102 of 411 extracted
# Data for chunk 103 of 411 extracted
# Data for chunk 104 of 411 extracted
# Data for chunk 105 of 411 extracted
# Data for chunk 106 of 411 extracted
# Data for chunk 107 of 411 extracted
# Data for chunk 108 of 411 extracted
# Data for chunk 109 of 411 extracted
# Data for chunk 110 of 411 extracted
# Data for chunk 111 of 411 extracted
# Data for chunk 112 of 411 extracted
# Data for chunk 113 of 411 extracted
# Data for chunk 114 of 411 extracted
# Data for chunk 115 of 411 extracted
# Data for chunk 116 of 411 extracted
# Data for chunk 117 of 411 extracted
# Data for chunk 118 of 411 extracted
# Data for chunk 119 of 411 extracted
# Data for chunk 120 of 411 extracted
# Data for chunk 121 of 411 extracted
# Data for chunk 122 of 411 extracted
# Data for chunk 123 of 411 extracted
# Data for chunk 124 of 411 extracted
# Data for chunk 125 of 411 extracted
# Data for chunk 126 of 411 extracted
# Data for chunk 127 of 411 extracted
# Data for chunk 128 of 411 extracted
# Data for chunk 129 of 411 extracted
# Data for chunk 130 of 411 extracted
# Data for chunk 131 of 411 extracted
# Data for chunk 132 of 411 extracted
# Data for chunk 133 of 411 extracted
# Data for chunk 134 of 411 extracted
# Data for chunk 135 of 411 extracted
# Data for chunk 136 of 411 extracted
# Data for chunk 137 of 411 extracted
# Data for chunk 138 of 411 extracted
# Data for chunk 139 of 411 extracted
# Data for chunk 140 of 411 extracted
# Data for chunk 141 of 411 extracted
# Data for chunk 142 of 411 extracted
# Data for chunk 143 of 411 extracted
# Data for chunk 144 of 411 extracted
# Data for chunk 145 of 411 extracted
# Data for chunk 146 of 411 extracted
# Data for chunk 147 of 411 extracted
# Data for chunk 148 of 411 extracted
# Data for chunk 149 of 411 extracted
# Data for chunk 150 of 411 extracted
# Data for chunk 151 of 411 extracted
# Data for chunk 152 of 411 extracted
# Data for chunk 153 of 411 extracted
# Data for chunk 154 of 411 extracted
# Data for chunk 155 of 411 extracted
# Data for chunk 156 of 411 extracted
# Data for chunk 157 of 411 extracted
# Data for chunk 158 of 411 extracted
# Data for chunk 159 of 411 extracted
# Data for chunk 160 of 411 extracted
# Data for chunk 161 of 411 extracted
# Data for chunk 162 of 411 extracted
# Data for chunk 163 of 411 extracted
# Data for chunk 164 of 411 extracted
# Data for chunk 165 of 411 extracted
# Data for chunk 166 of 411 extracted
# Data for chunk 167 of 411 extracted
# Data for chunk 168 of 411 extracted
# Data for chunk 169 of 411 extracted
# Data for chunk 170 of 411 extracted
# Data for chunk 171 of 411 extracted
# Data for chunk 172 of 411 extracted
# Data for chunk 173 of 411 extracted
# Data for chunk 174 of 411 extracted
# Data for chunk 175 of 411 extracted
# Data for chunk 176 of 411 extracted
# Data for chunk 177 of 411 extracted
# Data for chunk 178 of 411 extracted
# Data for chunk 179 of 411 extracted
# Data for chunk 180 of 411 extracted
# Data for chunk 181 of 411 extracted
# Data for chunk 182 of 411 extracted
# Data for chunk 183 of 411 extracted
# Data for chunk 184 of 411 extracted
# Data for chunk 185 of 411 extracted
# Data for chunk 186 of 411 extracted
# Data for chunk 187 of 411 extracted
# Data for chunk 188 of 411 extracted
# Data for chunk 189 of 411 extracted
# Data for chunk 190 of 411 extracted
# Data for chunk 191 of 411 extracted
# Data for chunk 192 of 411 extracted
# Data for chunk 193 of 411 extracted
# Data for chunk 194 of 411 extracted
# Data for chunk 195 of 411 extracted
# Data for chunk 196 of 411 extracted
# Data for chunk 197 of 411 extracted
# Data for chunk 198 of 411 extracted
# Data for chunk 199 of 411 extracted
# Data for chunk 200 of 411 extracted
# Data for chunk 201 of 411 extracted
# Data for chunk 202 of 411 extracted
# Data for chunk 203 of 411 extracted
# Data for chunk 204 of 411 extracted
# Data for chunk 205 of 411 extracted
# Data for chunk 206 of 411 extracted
# Data for chunk 207 of 411 extracted
# Data for chunk 208 of 411 extracted
# Data for chunk 209 of 411 extracted
# Data for chunk 210 of 411 extracted
# Data for chunk 211 of 411 extracted
# Data for chunk 212 of 411 extracted
# Data for chunk 213 of 411 extracted
# Data for chunk 214 of 411 extracted
# Data for chunk 215 of 411 extracted
# Data for chunk 216 of 411 extracted
# Data for chunk 217 of 411 extracted
# Data for chunk 218 of 411 extracted
# Data for chunk 219 of 411 extracted
# Data for chunk 220 of 411 extracted
# Data for chunk 221 of 411 extracted
# Data for chunk 222 of 411 extracted
# Data for chunk 223 of 411 extracted
# Data for chunk 224 of 411 extracted
# Data for chunk 225 of 411 extracted
# Data for chunk 226 of 411 extracted
# Data for chunk 227 of 411 extracted
# Data for chunk 228 of 411 extracted
# Data for chunk 229 of 411 extracted
# Data for chunk 230 of 411 extracted
# Data for chunk 231 of 411 extracted
# Data for chunk 232 of 411 extracted
# Data for chunk 233 of 411 extracted
# Data for chunk 234 of 411 extracted
# Data for chunk 235 of 411 extracted
# Data for chunk 236 of 411 extracted
# Data for chunk 237 of 411 extracted
# Data for chunk 238 of 411 extracted
# Data for chunk 239 of 411 extracted
# Data for chunk 240 of 411 extracted
# Data for chunk 241 of 411 extracted
# Data for chunk 242 of 411 extracted
# Data for chunk 243 of 411 extracted
# Data for chunk 244 of 411 extracted
# Data for chunk 245 of 411 extracted
# Data for chunk 246 of 411 extracted
# Data for chunk 247 of 411 extracted
# Data for chunk 248 of 411 extracted
# Data for chunk 249 of 411 extracted
# Data for chunk 250 of 411 extracted
# Data for chunk 251 of 411 extracted
# Data for chunk 252 of 411 extracted
# Data for chunk 253 of 411 extracted
# Data for chunk 254 of 411 extracted
# Data for chunk 255 of 411 extracted
# Data for chunk 256 of 411 extracted
# Data for chunk 257 of 411 extracted
# Data for chunk 258 of 411 extracted
# Data for chunk 259 of 411 extracted
# Data for chunk 260 of 411 extracted
# Data for chunk 261 of 411 extracted
# Data for chunk 262 of 411 extracted
# Data for chunk 263 of 411 extracted
# Data for chunk 264 of 411 extracted
# Data for chunk 265 of 411 extracted
# Data for chunk 266 of 411 extracted
# Data for chunk 267 of 411 extracted
# Data for chunk 268 of 411 extracted
# Data for chunk 269 of 411 extracted
# Data for chunk 270 of 411 extracted
# Data for chunk 271 of 411 extracted
# Data for chunk 272 of 411 extracted
# Data for chunk 273 of 411 extracted
# Data for chunk 274 of 411 extracted
# Data for chunk 275 of 411 extracted
# Data for chunk 276 of 411 extracted
# Data for chunk 277 of 411 extracted
# Data for chunk 278 of 411 extracted
# Data for chunk 279 of 411 extracted
# Data for chunk 280 of 411 extracted
# Data for chunk 281 of 411 extracted
# Data for chunk 282 of 411 extracted
# Data for chunk 283 of 411 extracted
# Data for chunk 284 of 411 extracted
# Data for chunk 285 of 411 extracted
# Data for chunk 286 of 411 extracted
# Data for chunk 287 of 411 extracted
# Data for chunk 288 of 411 extracted
# Data for chunk 289 of 411 extracted
# Data for chunk 290 of 411 extracted
# Data for chunk 291 of 411 extracted
# Data for chunk 292 of 411 extracted
# Data for chunk 293 of 411 extracted
# Data for chunk 294 of 411 extracted
# Data for chunk 295 of 411 extracted
# Data for chunk 296 of 411 extracted
# Data for chunk 297 of 411 extracted
# Data for chunk 298 of 411 extracted
# Data for chunk 299 of 411 extracted
# Data for chunk 300 of 411 extracted
# Data for chunk 301 of 411 extracted
# Data for chunk 302 of 411 extracted
# Data for chunk 303 of 411 extracted
# Data for chunk 304 of 411 extracted
# Data for chunk 305 of 411 extracted
# Data for chunk 306 of 411 extracted
# Data for chunk 307 of 411 extracted
# Data for chunk 308 of 411 extracted
# Data for chunk 309 of 411 extracted
# Data for chunk 310 of 411 extracted
# Data for chunk 311 of 411 extracted
# Data for chunk 312 of 411 extracted
# Data for chunk 313 of 411 extracted
# Data for chunk 314 of 411 extracted
# Data for chunk 315 of 411 extracted
# Data for chunk 316 of 411 extracted
# Data for chunk 317 of 411 extracted
# Data for chunk 318 of 411 extracted
# Data for chunk 319 of 411 extracted
# Data for chunk 320 of 411 extracted
# Data for chunk 321 of 411 extracted
# Data for chunk 322 of 411 extracted
# Data for chunk 323 of 411 extracted
# Data for chunk 324 of 411 extracted
# Data for chunk 325 of 411 extracted
# Data for chunk 326 of 411 extracted
# Data for chunk 327 of 411 extracted
# Data for chunk 328 of 411 extracted
# Data for chunk 329 of 411 extracted
# Data for chunk 330 of 411 extracted
# Data for chunk 331 of 411 extracted
# Data for chunk 332 of 411 extracted
# Data for chunk 333 of 411 extracted
# Data for chunk 334 of 411 extracted
# Data for chunk 335 of 411 extracted
# Data for chunk 336 of 411 extracted
# Data for chunk 337 of 411 extracted
# Data for chunk 338 of 411 extracted
# Data for chunk 339 of 411 extracted
# Data for chunk 340 of 411 extracted
# Data for chunk 341 of 411 extracted
# Data for chunk 342 of 411 extracted
# Data for chunk 343 of 411 extracted
# Data for chunk 344 of 411 extracted
# Data for chunk 345 of 411 extracted
# Data for chunk 346 of 411 extracted
# Data for chunk 347 of 411 extracted
# Data for chunk 348 of 411 extracted
# Data for chunk 349 of 411 extracted
# Data for chunk 350 of 411 extracted
# Data for chunk 351 of 411 extracted
# Data for chunk 352 of 411 extracted
# Data for chunk 353 of 411 extracted
# Data for chunk 354 of 411 extracted
# Data for chunk 355 of 411 extracted
# Data for chunk 356 of 411 extracted
# Data for chunk 357 of 411 extracted
# Data for chunk 358 of 411 extracted
# Data for chunk 359 of 411 extracted
# Data for chunk 360 of 411 extracted
# Data for chunk 361 of 411 extracted
# Data for chunk 362 of 411 extracted
# Data for chunk 363 of 411 extracted
# Data for chunk 364 of 411 extracted
# Data for chunk 365 of 411 extracted
# Data for chunk 366 of 411 extracted
# Data for chunk 367 of 411 extracted
# Data for chunk 368 of 411 extracted
# Data for chunk 369 of 411 extracted
# Data for chunk 370 of 411 extracted
# Data for chunk 371 of 411 extracted
# Data for chunk 372 of 411 extracted
# Data for chunk 373 of 411 extracted
# Data for chunk 374 of 411 extracted
# Data for chunk 375 of 411 extracted
# Data for chunk 376 of 411 extracted
# Data for chunk 377 of 411 extracted
# Data for chunk 378 of 411 extracted
# Data for chunk 379 of 411 extracted
# Data for chunk 380 of 411 extracted
# Data for chunk 381 of 411 extracted
# Data for chunk 382 of 411 extracted
# Data for chunk 383 of 411 extracted
# Data for chunk 384 of 411 extracted
# Data for chunk 385 of 411 extracted
# Data for chunk 386 of 411 extracted
# Data for chunk 387 of 411 extracted
# Data for chunk 388 of 411 extracted
# Data for chunk 389 of 411 extracted
# Data for chunk 390 of 411 extracted
# Data for chunk 391 of 411 extracted
# Data for chunk 392 of 411 extracted
# Data for chunk 393 of 411 extracted
# Data for chunk 394 of 411 extracted
# Data for chunk 395 of 411 extracted
# Data for chunk 396 of 411 extracted
# Data for chunk 397 of 411 extracted
# Data for chunk 398 of 411 extracted
# Data for chunk 399 of 411 extracted
# Data for chunk 400 of 411 extracted
# Data for chunk 401 of 411 extracted
# Data for chunk 402 of 411 extracted
# Data for chunk 403 of 411 extracted
# Data for chunk 404 of 411 extracted
# Data for chunk 405 of 411 extracted
# Data for chunk 406 of 411 extracted
# Data for chunk 407 of 411 extracted
# Data for chunk 408 of 411 extracted
# Data for chunk 409 of 411 extracted
# Data for chunk 410 of 411 extracted
# Data for chunk 411 of 411 extracted

# %%
# start_date=pd.Timestamp("2019-07-01").isoformat()
# end_date=pd.Timestamp("2019-07-01").isoformat()

from datetime import date

start_date = date(2019,7,1).isoformat()
end_date = date(2019,7,2).isoformat()

# %%
data = pd.DataFrame(c.get_products())
data.tail().T
# Out:
#                          242        243        244         245         246
# id                   ADA-BTC  MATIC-USD  MASK-USDT     LTC-USD    LINK-BTC
# base_currency            ADA      MATIC       MASK         LTC        LINK
# quote_currency           BTC        USD       USDT         USD         BTC
# base_min_size              1          5        0.1        0.01         0.1
# base_max_size         250000    1000000      67000        4000        6500
# quote_increment   0.00000001     0.0001       0.01        0.01  0.00000001
# base_increment          0.01        0.1       0.01  0.00000001        0.01
# display_name         ADA/BTC  MATIC/USD  MASK/USDT     LTC/USD    LINK/BTC
# min_market_funds      0.0001        5.0        5.0          10      0.0001
# max_market_funds           2     100000     100000      250000         6.0
# margin_enabled         False      False      False       False       False
# fx_stablecoin          False      False      False       False       False
# post_only              False      False      False       False       False
# limit_only             False      False       True       False       False
# cancel_only            False      False      False       False       False
# trading_disabled       False      False      False       False       False
# status                online     online     online      online      online
# status_message

# %%
historical = pd.DataFrame(c.get_product_historic_rates('ETH-USD',granularity=300, start=start_date, end=end_date))
historical.columns= ["Date","Open","High","Low","Close","Volume"]
historical['Date'] = pd.to_datetime(historical['Date'], unit='s')
historical.set_index('Date', inplace=True)
historical.sort_values(by='Date', ascending=True, inplace=True)
historical
# Out:
#                        Open    High     Low   Close       Volume
# Date
# 2019-07-01 00:00:00  288.00  291.20  290.08  288.18  1571.670614
# 2019-07-01 00:05:00  286.69  290.55  288.32  290.50  2555.752090
# 2019-07-01 00:10:00  289.50  293.54  290.50  292.48  2763.347967
# 2019-07-01 00:15:00  290.32  292.66  292.47  291.34  1462.253660
# 2019-07-01 00:20:00  290.81  292.53  291.23  291.16   917.931374
# ...                     ...     ...     ...     ...          ...
# 2019-07-01 23:40:00  292.92  293.94  293.71  293.11   178.998026
# 2019-07-01 23:45:00  293.01  294.63  293.17  294.14   419.830997
# 2019-07-01 23:50:00  293.63  294.35  294.07  294.15   396.646661
# 2019-07-01 23:55:00  293.37  294.16  294.16  293.70   313.261033
# 2019-07-02 00:00:00  293.57  295.55  293.72  295.29   538.474244
#
# [289 rows x 5 columns]

# %%
ticker = c.get_product_ticker(product_id='ADA-USD')
ticker
# Out:
# {'trade_id': 23050677,
#  'price': '1.3704',
#  'size': '18.97',
#  'time': '2021-08-05T01:24:29.839142Z',
#  'bid': '1.3704',
#  'ask': '1.3705',
#  'volume': '44318331.65'}
